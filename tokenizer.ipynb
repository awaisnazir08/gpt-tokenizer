# %%
text = "Unicode! 😊 $ these are the legends of the kung fu panda. The very name strikes fear and awe into the hearts of programmers everywhere. Some special characters and emojis are:    📚 Sources Being Researched 🔗 Universities Ranking - HEC 🔗 University Overall Rankings - Computer Science - Pakistan 2025"
tokens = text.encode('utf-8') # raw bytessplit(b' ')
print(tokens)
# Out:
# b'Unicode! \xf0\x9f\x98\x8a $ these are the legends of the kung fu panda. The very name strikes fear and awe into the hearts of programmers everywhere. Some special characters and emojis are:    \xf0\x9f\x93\x9a Sources Being Researched \xf0\x9f\x94\x97 Universities Ranking - HEC \xf0\x9f\x94\x97 University Overall Rankings - Computer Science - Pakistan 2025'

# %%
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience
print('----')
print(text)
print("length: ", len(text))

print("----")
print(tokens)
print("length: ", len(tokens))
# Out:
# ----
# Unicode! 😊 $ these are the legends of the kung fu panda. The very name strikes fear and awe into the hearts of programmers everywhere. Some special characters and emojis are:    📚 Sources Being Researched 🔗 Universities Ranking - HEC 🔗 University Overall Rankings - Computer Science - Pakistan 2025
# length:  298
# ----
# ...

# %%
def get_stats(ids):
    counts = {}
    for pair in zip(ids, ids[1:]): # pythonic way to get pairs
        counts[pair] = counts.get(pair, 0) + 1
    return counts

stats = get_stats(tokens)
print(stats)

sorted(((value, key) for (key, value) in stats.items()), reverse=True)
# Out:
# {(85, 110): 3, (110, 105): 3, (105, 99): 1, (99, 111): 1, (111, 100): 1, (100, 101): 1, (101, 33): 1, (33, 32): 1, (32, 240): 4, (240, 159): 4, (159, 152): 1, (152, 138): 1, (138, 32): 1, (32, 36): 1, (36, 32): 1, (32, 116): 4, (116, 104): 4, (104, 101): 8, (101, 115): 5, (115, 101): 2, (101, 32): 10, (32, 97): 5, (97, 114): 6, (114, 101): 3, (32, 108): 1, (108, 101): 1, (101, 103): 1, (103, 101): 1, (101, 110): 2, (110, 100): 4, (100, 115): 1, (115, 32): 9, (32, 111): 2, (111, 102): 2, (102, 32): 2, (32, 107): 1, (107, 117): 1, (117, 110): 1, (110, 103): 4, (103, 32): 3, (32, 102): 2, (102, 117): 1, (117, 32): 1, (32, 112): 2, (112, 97): 1, (97, 110): 6, (100, 97): 1, (97, 46): 1, (46, 32): 2, (32, 84): 1, (84, 104): 1, (32, 118): 1, (118, 101): 5, (101, 114): 9, (114, 121): 2, (121, 32): 2, (32, 110): 1, (110, 97): 1, (97, 109): 2, (109, 101): 3, (32, 115): 2, (115, 116): 2, (116, 114): 1, (114, 105): 1, (105, 107): 1, (107, 101): 1, (102, 101): 1, (101, 97): 3, (114, 32): 2, (100,
# ...
